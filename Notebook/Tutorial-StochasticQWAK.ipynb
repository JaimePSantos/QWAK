# %%
from qwak.qwak import QWAK
from qwak.StochasticOperator import StochasticOperator

# from sqwalk import SQWalker

import networkx as nx
import numpy as np
from matplotlib import pyplot as plt
import timeit
import sympy as sp
from sympy.abc import pi
from math import sqrt, ceil, pow

# %%
n = 100
graph = nx.path_graph(n)
adj = nx.adj_matrix(graph).todense()
time_samples = 1200
initial_node = n // 2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 n = 100
#       2 graph = nx.path_graph(n)
# ----> 3 adj = nx.adj_matrix(graph).todense()
#       4 time_samples = 1200
#       5 initial_node = n // 2
#
# AttributeError: module 'networkx' has no attribute 'adj_matrix'

# %%
# walker = SQWalker(np.array(adj), noise_param=0.0, sink_node=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 walker = SQWalker(np.array(adj), noise_param=0.0, sink_node=None)
#
# NameError: name 'SQWalker' is not defined

# %%
# result = walker.run_walker(initial_node, time_samples)
# new_state = result.final_state
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 result = walker.run_walker(initial_node, time_samples)
#       2 new_state = result.final_state
#
# NameError: name 'walker' is not defined

# %%
# plt.plot(new_state.diag())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 plt.plot(new_state.diag())
#
# NameError: name 'new_state' is not defined

# %%
n = 100
t = 12
graph = nx.cycle_graph(n)
init = [int(n / 2)]

# %%
qwController = QWAK(graph, laplacian=False)
qwController.runWalk(t, init)

# %%
plt.plot(qwController.getProbVec())

# %%
n = 100
time_samples = 1200
initial_node = n // 2

# %%
sQWAK = StochasticOperator(nx.cycle_graph(n), noiseParam=0.5, sinkNode=None)
# result = sQWAK.run_walker(initial_node, time_samples)
# new_state = result.final_state

# %%
# plt.plot(new_state.diag())
